# %%
import pandas as pd
import pickle
import requests
import category_encoders as ce
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from xgboost import XGBRegressor
import numpy as np
import json# Importing the dataset

# %%
df = pd.read_csv('/Users/tako/Desktop/repos/DS/zillow-prize-1/properties_2017.csv')
df = df[['bedroomcnt', 'bathroomcnt', 'regionidzip', 'taxvaluedollarcnt']]
# Out:
# C:\Users\tako\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.dropna()

# %%
X = df.drop('taxvaluedollarcnt', axis=1)
y = df['taxvaluedollarcnt']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# %%
target = 'taxvaluedollarcnt'
y_train_log = np.log1p(y_train)
y_test_log = np.log1p(y_test)
y_val_log = np.log1p(y_val)

# %%
encoder = ce.OrdinalEncoder()
xtre = encoder.fit_transform(X_train)
xve = encoder.transform(X_val)

# %%
X_test = encoder.transform(X_test)

# %%
eval_set = [(xtre, y_train), (xve, y_val)]

# %%
#model = XGBRegressor(n_estimators=50, n_jobs=-1)
#model.fit(xtre, y_train_log, eval_set=eval_set, eval_metric='rmse', early_stopping_rounds=50)

model = XGBRegressor(n_estimators=50, n_jobs=-1)
model.fit(xtre, y_train, eval_set=eval_set, eval_metric='rmse', early_stopping_rounds=20)
# Out:
# [15:42:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:841908	validation_1-rmse:838475
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:814548	validation_1-rmse:811015
# [2]	validation_0-rmse:791595	validation_1-rmse:787876
# [3]	validation_0-rmse:772260	validation_1-rmse:768435
# [4]	validation_0-rmse:756204	validation_1-rmse:752125
# [5]	validation_0-rmse:742713	validation_1-rmse:738571
# [6]	validation_0-rmse:730844	validation_1-rmse:727320
# [7]	validation_0-rmse:720792	validation_1-rmse:717321
# [8]	validation_0-rmse:712889	validation_1-rmse:709222
# [9]	validation_0-rmse:705880	validation_1-rmse:702536
# [10]	validation_0-rmse:699955	validation_1-rmse:696660
# [11]	validation_0-rmse:695084	validation_1-rmse:691753
# [12]	validation_0-rmse:690951	validation_1-rmse:687799
# [13]	validation_0-rmse:686926	validation_1-rmse:683981
# [14]	validation_0-rmse:683637	validation_1-rmse:680657
# [15]	validation_0-rmse:680871	validation_1-rmse:678004
# [16]	validation_0-rmse:678636	validation_1-rmse:676014
# [17]	validation_0-rmse:676415	validation_1-rmse:673971
# [18]	validation_0-rmse:674304	validation_1-rmse:671921
# [19]	validation_0-rmse:672619	validation_1-rmse:670283
# [20]	validation_0-rmse:671346	validation_1-rmse:668831
# [21]	validation_0-rmse:669991	validation_1-rmse:667509
# [22]	validation_0-rmse:668704	validation_1-rmse:666240
# [23]	validation_0-rmse:667420	validation_1-rmse:665176
# [24]	validation_0-rmse:666500	validation_1-rmse:664509
# [25]	validation_0-rmse:665736	validation_1-rmse:663695
# [26]	validation_0-rmse:664795	validation_1-rmse:662878
# [27]	validation_0-rmse:663921	validation_1-rmse:662299
# [28]	validation_0-rmse:663204	validation_1-rmse:661591
# [29]	validation_0-rmse:662540	validation_1-rmse:660865
# [30]	validation_0-rmse:661897	validation_1-rmse:660260
# [31]	validation_0-rmse:661083	validation_1-rmse:659471
# [32]	validation_0-rmse:660572	validation_1-rmse:659187
# [33]	validation_0-rmse:659903	validation_1-rmse:658859
# [34]	validation_0-rmse:659476	validation_1-rmse:658483
# [35]	validation_0-rmse:658850	validation_1-rmse:657879
# [36]	validation_0-rmse:658609	validation_1-rmse:657628
# [37]	validation_0-rmse:658075	validation_1-rmse:657067
# [38]	validation_0-rmse:657753	validation_1-rmse:656924
# [39]	validation_0-rmse:657435	validation_1-rmse:656644
# [40]	validation_0-rmse:657027	validation_1-rmse:656408
# [41]	validation_0-rmse:656307	validation_1-rmse:655852
# [42]	validation_0-rmse:655838	validation_1-rmse:655333
# [43]	validation_0-rmse:655498	validation_1-rmse:655058
# [44]	validation_0-rmse:654996	validation_1-rmse:654526
# [45]	validation_0-rmse:654586	validation_1-rmse:654423
# [46]	validation_0-rmse:654360	validation_1-rmse:654323
# [47]	validation_0-rmse:653786	validation_1-rmse:653775
# [48]	validation_0-rmse:653618	validation_1-rmse:653665
# [49]	validation_0-rmse:653116	validation_1-rmse:653148
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=50,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
import pickle
xgb_pickle = open('model.pkl','wb')
pickle.dump(model, xgb_pickle)# Loading model to compare the results
xgb_pickle.close()

# %%
X.head(100)
# Out:
#     bedroomcnt  bathroomcnt  regionidzip
# 0          0.0          0.0      96337.0
# 1          0.0          0.0      96337.0
# 2          0.0          0.0      96095.0
# 3          0.0          0.0      96424.0
# 4          0.0          0.0      96450.0
# 5          0.0          0.0      96446.0
# 6          0.0          0.0      96049.0
# 7          0.0          0.0      96434.0
# 8          0.0          0.0      96436.0
# 9          0.0          0.0      96366.0
# 10         4.0          4.0      96356.0
# 11         0.0          0.0      96370.0
# 12         0.0          0.0      96377.0
# 13         0.0          0.0      96377.0
# 14         0.0          0.0      96373.0
# 15         0.0          0.0      97329.0
# 16         0.0          0.0      97330.0
# 17         0.0          0.0      97330.0
# 18         0.0          0.0      97317.0
# 19         0.0          0.0      97318.0
# 20         4.0          2.0      97329.0
# 21         0.0          0.0      96024.0
# 22         0.0          0.0      96137.0
# 23         0.0          0.0      96133.0
# 24         0.0          0.0      96133.0
# 25         0.0          0.0      96136.0
# 26         0.0          0.0      96107.0
# 27         0.0          0.0      96026.0
# 28         5.0          4.0      96124.0
# 29         0.0          0.0      96097.0
# ..         ...          ...          ...
# 70         0.0          0.0      96325.0
# 71         0.0          0.0      96325.0
# 72         2.0          3.0      96293.0
# 73         0.0          0.0      96291.0
# 74         0.0          0.0      96289.0
# 75         4.0          4.0      96268.0
# 76         0.0          0.0      96265.0
# 77         0.0          0.0      96292.0
# 78         0.0          0.0      95984.0
# 79         0.0          0.0      96025.0
# 80         0.0          0.0      96028.0
# 81         0.0          0.0      95984.0
# 82         0.0          0.0      96042.0
# 83         0.0          0.0      96104.0
# 84         0.0          0.0      96042.0
# 85         0.0          0.0      96125.0
# 86         0.0          0.0      96125.0
# 87         0.0          0.0      96220.0
# 88         0.0          0.0      96110.0
# 89         0.0          0.0      96083.0
# 90         0.0          0.0      96003.0
# 91         0.0          0.0      96192.0
# 92         0.0          0.0      96206.0
# 93         0.0          0.0      96206.0
# 94         0.0          0.0      96239.0
# 95         0.0          0.0      96208.0
# 96         0.0          3.0      96234.0
# 97         0.0          0.0      96246.0
# 98         0.0          0.0      96245.0
# 99         0.0          0.0      96236.0
#
# [100 rows x 3 columns]

# %%
import requests
import json
url = 'http://localhost:5000/'
data = {'bedroomcnt': 10
      , 'bathroomcnt': 5
      , 'regionidzip': 96234}
data = json.dumps(data)

# %%
send_request = requests.post(url, data)
print(send_request)
# Out:
# <Response [200]>

# %%
print(send_request.json())
# Out:
# {'results': {'results': 647809.3125}}

# %%
result = model.predict(X_test[:10:])

# %%
result
# Out:
# array([325619.78, 360469.22, 311901.22, 491742.9 , 273602.2 , 433738.06,
#        325619.78, 360469.22, 325619.78, 433738.06], dtype=float32)
